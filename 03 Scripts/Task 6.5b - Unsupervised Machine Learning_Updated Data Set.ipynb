# %% [markdown]
# # 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.cluster import KMeans
import pylab as pl

# %%
# %matplotlib inline

# %% [markdown]
# # 02. Importing Data

# %%
path = r'C:\Users\Rebecca\Library Funding and Literacy Rates'

# %%
path
# Out:
# 'C:\\Users\\Rebecca\\Library Funding and Literacy Rates'

# %%
df_county = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'county_nonimpute.csv'), index_col = False, encoding='latin1')

# %%
df_county.head()
# Out:
#    Unnamed: 0  FIPS_code    State          County grpName  Lit_P1  Lit_P2  \
# 0           0       1001  Alabama  Autauga County     all   0.205   0.384
# 1           1       1003  Alabama  Baldwin County     all   0.161   0.347
# 2           2       1005  Alabama  Barbour County     all   0.394   0.404
# 3           3       1007  Alabama     Bibb County     all   0.269   0.454
# 4           4       1009  Alabama   Blount County     all   0.248   0.370
#
#    Lit_P3  Lit_A  Population  ...  Unemployed  Not_in_labor  OCC_Manage  \
# 0   0.411  261.7     39765.0  ...       0.037         0.287       0.348
# 1   0.493  270.3    148385.0  ...       0.040         0.288       0.361
# 2   0.201  235.9     19450.0  ...       0.073         0.444       0.254
# 3   0.277  248.1     16970.0  ...       0.048         0.442       0.245
# 4   0.382  258.5     41955.0  ...       0.029         0.402       0.286
#
#    OCC_Service  OCC_Sales  OCC_Natural  OCC_Military  OCC_Prod  No_Insurance  \
# 0        0.179      0.226        0.081         0.011     0.153         0.088
# 1        0.180      0.257        0.096         0.000     0.106         0.108
# 2        0.168      0.225        0.114         0.000     0.239         0.123
# 3        0.178      0.196        0.153         0.000     0.228         0.081
# 4        0.129      0.233        0.158         0.000     0.193         0.110
#
#    Total Literacy Score
# 0      Average Literacy
# 1      Average Literacy
# 2      Average Literacy
# 3      Average Literacy
# 4      Average Literacy
#
# [5 rows x 41 columns]

# %%
# Removing categorical columns

df_county_dropped = df_county.drop(columns=['Unnamed: 0', 'State', 'County', 'grpName', 'Total Literacy Score'])

# %%
df_county_dropped.head()
# Out:
#    FIPS_code  Lit_P1  Lit_P2  Lit_P3  Lit_A  Population   Male  Female  White  \
# 0       1001   0.205   0.384   0.411  261.7     39765.0  0.489   0.511  0.766
# 1       1003   0.161   0.347   0.493  270.3    148385.0  0.489   0.511  0.865
# 2       1005   0.394   0.404   0.201  235.9     19450.0  0.533   0.467  0.466
# 3       1007   0.269   0.454   0.277  248.1     16970.0  0.543   0.457  0.767
# 4       1009   0.248   0.370   0.382  258.5     41955.0  0.494   0.506  0.955
#
#    Black  ...  Employed  Unemployed  Not_in_labor  OCC_Manage  OCC_Service  \
# 0  0.191  ...     0.662       0.037         0.287       0.348        0.179
# 1  0.095  ...     0.670       0.040         0.288       0.361        0.180
# 2  0.480  ...     0.483       0.073         0.444       0.254        0.168
# 3  0.221  ...     0.511       0.048         0.442       0.245        0.178
# 4  0.016  ...     0.568       0.029         0.402       0.286        0.129
#
#    OCC_Sales  OCC_Natural  OCC_Military  OCC_Prod  No_Insurance
# 0      0.226        0.081         0.011     0.153         0.088
# 1      0.257        0.096         0.000     0.106         0.108
# 2      0.225        0.114         0.000     0.239         0.123
# 3      0.196        0.153         0.000     0.228         0.081
# 4      0.233        0.158         0.000     0.193         0.110
#
# [5 rows x 36 columns]

# %%
df_county_dropped.shape
# Out:
# (3141, 36)

# %% [markdown]
# # 03. K-means Algorithm

# %% [markdown]
# ### The Elbow Technique

# %%
# The elbow technique

num_cl = range(1, 10)
kmeans = [KMeans(n_clusters=i) for i in num_cl]

# %%
score = [kmeans[i].fit(df_county_dropped).score(df_county_dropped) for i in range(len(kmeans))] 

score
# Out:
# C:\Users\Rebecca\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Rebecca\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\Rebecca\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Rebecca\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\Rebecca\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [-185653537900641.72,
#  -90178131399928.64,
#  -52233120415749.4,
#  -28831824780134.01,
#  -16517175364878.152,
#  -9510969548335.824,
#  -7288047054341.451,
#  -5373923059716.72,
#  -4353481788812.0176]

# %%
# Plot the elbow curve

pl.plot(num_cl,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.show()

# %% [markdown]
# #### This elbow curve starts to straighten out after 3 clusters.

# %% [markdown]
# ### K-Means Clustering

# %%
# Create the k-means object.

kmeans = KMeans(n_clusters = 3)

# %%
# Fit the k-means object to the data.

kmeans.fit(df_county_dropped)
# Out:
# KMeans(n_clusters=3)

# %%
df_county_dropped['clusters'] = kmeans.fit_predict(df_county_dropped)

# %%
df_county_dropped.head()
# Out:
#    FIPS_code  Lit_P1  Lit_P2  Lit_P3  Lit_A  Population   Male  Female  White  \
# 0       1001   0.205   0.384   0.411  261.7     39765.0  0.489   0.511  0.766
# 1       1003   0.161   0.347   0.493  270.3    148385.0  0.489   0.511  0.865
# 2       1005   0.394   0.404   0.201  235.9     19450.0  0.533   0.467  0.466
# 3       1007   0.269   0.454   0.277  248.1     16970.0  0.543   0.457  0.767
# 4       1009   0.248   0.370   0.382  258.5     41955.0  0.494   0.506  0.955
#
#    Black  ...  Unemployed  Not_in_labor  OCC_Manage  OCC_Service  OCC_Sales  \
# 0  0.191  ...       0.037         0.287       0.348        0.179      0.226
# 1  0.095  ...       0.040         0.288       0.361        0.180      0.257
# 2  0.480  ...       0.073         0.444       0.254        0.168      0.225
# 3  0.221  ...       0.048         0.442       0.245        0.178      0.196
# 4  0.016  ...       0.029         0.402       0.286        0.129      0.233
#
#    OCC_Natural  OCC_Military  OCC_Prod  No_Insurance  clusters
# 0        0.081         0.011     0.153         0.088         0
# 1        0.096         0.000     0.106         0.108         0
# 2        0.114         0.000     0.239         0.123         0
# 3        0.153         0.000     0.228         0.081         0
# 4        0.158         0.000     0.193         0.110         0
#
# [5 rows x 37 columns]

# %%
# Checking cluster counts

df_county_dropped['clusters'].value_counts()
# Out:
# clusters
# 0    3033
# 2     104
# 1       4
# Name: count, dtype: int64

# %% [markdown]
# ### Cluster Visualizations

# %%
# Plot the clusters for the "Lit_A" and "Employed" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_county_dropped['Lit_A'], y=df_county_dropped['Employed'], hue=kmeans.labels_, s=100) 

ax.grid(False)
plt.xlabel('Average Literacy')
plt.ylabel('Employed') 
plt.show()

# %% [markdown]
# #### Both values are grouped closely together and do trend upwards, which makes sense - higher literacy means higher employment. Most dots are grouped tightly together, meaning that there isn't a big difference between counties and the variables are strongly correlated.

# %%
# Plot the clusters for the "Lit_A" and "Less_HS" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_county_dropped['Lit_A'], y=df_county_dropped['Less_HS'], hue=kmeans.labels_, s=100) 

ax.grid(False)
plt.xlabel('Average Literacy')
plt.ylabel('Less than High School Education') 
plt.show()

# %% [markdown]
# #### This graph shows a distinct downward path, meaning as literacy goes up/increases, the number of people with less than a high school education goes down. These data points are a bit more spread out throughout the downward trend (but are still tightly together), unlike the previous graph. Average Literacy and less than High School education may be slightly different between counties.

# %%
# Plot the clusters for the "Lit_P3" and "Poverty_150" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_county_dropped['Lit_P3'], y=df_county_dropped['Poverty_150'], hue=kmeans.labels_, s=100) 

ax.grid(False)
plt.xlabel('High Level of  Literacy')
plt.ylabel('Below 150% Poverty Level') 
plt.show()

# %% [markdown]
# #### This graph shows a downward path, showing that individuals who have a higher level of literacy have a low chance of being under poverty level. The clusters are fairly close together, so counties seem to be similar.

# %% [markdown]
# #### Overall, all scatterplots are showing clusters closely together and there are no scatterplots that showed clusters clustering together (separately), all of mine are all clustered together. This could mean that the data is too homogeneous and that there isn't a meaningful distinction between counties when we look at literacy, education, or employment. There doesn't seem to be any true subgroups in the county data set.

# %% [markdown]
# ### Descriptive Statistics

# %%
df_county_dropped.loc[df_county_dropped['clusters'] == 0, 'cluster'] = 'pink'
df_county_dropped.loc[df_county_dropped['clusters'] == 1, 'cluster'] = 'purple'
df_county_dropped.loc[df_county_dropped['clusters'] == 2, 'cluster'] = 'blue'

# %%
df_county_dropped.groupby('cluster').agg({'Employed':['mean', 'median'], 
    'Lit_A':['mean', 'median'],
    'Less_HS':['mean', 'median'], 
    'Poverty_150':['mean', 'median'],
    'Lit_P3':['mean', 'median']})
# Out:
#          Employed               Lit_A           Less_HS         Poverty_150  \
#              mean  median        mean  median      mean  median        mean
# cluster
# blue     0.701356  0.7105  265.134615  268.60  0.121904  0.1090    0.222538
# pink     0.656861  0.6640  259.819189  261.50  0.138579  0.1250    0.267489
# purple   0.687500  0.6910  255.175000  253.75  0.170000  0.1665    0.265250
#
#                    Lit_P3
#          median      mean  median
# cluster
# blue     0.2245  0.483529  0.5000
# pink     0.2610  0.400454  0.4050
# purple   0.2655  0.421250  0.4235

# %% [markdown]
# #### Clusters with highest means:
#     Employed: blue
#     Averge Literacy: blue
#     Less than high school education: purple
#     Below 150% poverty: pink
#     Low Literacy: blue

# %% [markdown]
# # 04. Future Steps for Analysis

# %% [markdown]
# #### The blue cluster has the highest mean in three groups: Employed, Average Literacy, and Low Literacy. I'd like to know which counties and states primarily make up this cluster and how this audience compares to the public library data set.
# #### The pink cluster has the highest mean in poverty level and the purple cluster has the highest mean in less than high school education. It would be good to understand what states are made up of these clusters, population size, and public libarary usage.

# %%
# Exporting cluster dataset

df_county_dropped.to_csv(os.path.join(path, '02 Data','Prepared Data', 'nonimpute_county_with_clusters.csv'))
